# %% [markdown]
# # Sample Notebook
# A quick demo of libraries available in `jupyter/scipy-notebook`.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Create a sample dataframe
df = pd.DataFrame({
    'date': pd.date_range('2025-01-01', periods=30, freq='D'),
    'sales': np.random.randint(100, 500, size=30),
    'region': np.random.choice(['North', 'South', 'East', 'West'], size=30)
})
df.head(10)

# %%
# Group by region
summary = df.groupby('region')['sales'].agg(['mean', 'sum', 'count'])
summary

# %%
# Plot sales over time
plt.figure(figsize=(10, 4))
plt.plot(df['date'], df['sales'], marker='o')
plt.title('Daily Sales')
plt.xlabel('Date')
plt.ylabel('Sales')
plt.grid(True)
plt.tight_layout()
plt.show()
